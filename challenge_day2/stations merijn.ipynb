# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('station6.csv')


x = data['s_input']
y = data['s_output']

plt.scatter(x, y)
plt.xlabel('Input')
plt.ylabel('Output')
plt.title('Station 6')
plt.show()

# %%
d+c = 11
d*a = 21
e+a+d = 10.5
c+b = 3
d*e = 3.5
e+b = -0.5

a=3
b=-1
c=4
d=7
e=0.5

eval()
